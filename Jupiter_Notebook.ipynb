# %% [markdown]
# # Simulation des nombre aléatoire

# %% [markdown]
# 1 ere partie: la génération des nombres aléatoires qui suit la loi exponentielle pour les utiliser dans la simulation d'un système d'attente M/M/S

# %%
# !pip install simpy
import math
# Out:
# Requirement already satisfied: simpy in c:\programdata\anaconda3\lib\site-packages (4.0.1)
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 20.1b1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# Je vais utiliser le GCL pour générer des nombres aléatoires qui suivent la loi uniforme, la fonction GCL permet aux utilisateurs de paramétrer le générateur, pour le reste de ce Tp je vais utiliser la version de GCL utilise par le GCC qui a comme paramètres :
#     a=1103515245
#     c=12345
#     m=(2)^31=2147483648

# %%
def GCL(m, a, c, seed):
   while True:
        seed = (a * seed + c) % m
        yield seed
def GCL_GCC(seed):
    while True:
        seed = (1103515245 * seed + 12345) % 2147483648
        yield seed

# %% [markdown]
# Pour avoir des nombres entre 0 et 1 je vais diviser les résultats de la fonction GCL_GCC par m=2147483648

# %%
def uniform_0_1(seed): 
    for i in GCL_GCC(seed):
        yield i/2147483648

# %% [markdown]
# Exemples des résultats des fonctions précédentes avec seed = 10 :

# %%
seed=10
j=0
print("suite de 5 nombres aléatoires par le générateur de GCC")
for i in GCL_GCC(seed):
    if(j==5):
        break
    j+=1
    print(i, end=" ")
print("\n")
print("suite de 5 nombres aléatoires qui suit la loi uniforme entre 0 et 1 ")
j=0
for i in uniform_0_1(seed):
    if(j==5):
        break
    j+=1
    print(float("{0:.2f}".format(i)), end=" ")
# Out:
# suite de 5 nombres aléatoires par le générateur de GCC
# 297746555 1849040536 736986865 581309142 1106733399
#
# suite de 5 nombres aléatoires qui suit la loi uniforme entre 0 et 1
# 0.14 0.86 0.34 0.27 0.52

# %% [markdown]
# pour la génération des nombres aléatoires qui suivent la loi exponentielle j'utilise la méthode de fonction inverse vue en cours qui est :
# 1- Générer ܷU ↝ ܷU[0,1]
# 2- calculer X= -(1/λ)log(U) ~ EXP(λ)

# %%
def Exp(λ,seed): 
    for i in uniform_0_1(seed):
        yield -(1/λ) * math.log(i)

# %% [markdown]
# Exemple d'une suite de 5 nombres aléatoire qui suivent la loi exponentielle générée par la fonction EXP avec seed= 3 et λ = 0.1:

# %%
seed = 3
λ = 0.1
j=0
print("Suite de 5 nombre aléatoire qui suit la loi exponentiel de parametre λ = 0.1")
for i in Exp(λ,seed):
    if(j==5):
        break
    j+=1
    print(float("{0:.2f}".format(i)), end=" ")
# Out:
# Suite de 5 nombre aléatoire qui suit la loi exponentiel de parametre λ = 0.1
# 6.13 15.28 11.51 13.72 4.63

# %% [markdown]
# 2éme partie : simulation d'un systeme d'attente M/M/S

# %% [markdown]
# Pour la simulation je vais utiliser le package Simpy qui offre un environnement d'exécution des tâches "processus" (services dans notre cas)qui s'exécutent sur des machines "ressources" (serveurs dans notre cas) à travers des  évènement "events" (l'arrivée et le départ des clients dans notre cas")

# %%
from statistics import mean
import simpy

# %% [markdown]
# je vais specifier :
# 1- le seed
# 2- le nombre de serveurs S
# 3- nombre initial de clients dans la fil Nmbr_Q

# %%
SEED = 7
nmbr_serveurs =6
temps_de_simulation =100
Nmbr_Q =0 
historique_de_systeme = []
temps_de_service = []
temps_de_sejour =[]

# %% [markdown]
# je vais créer un class système qui contient deux fonctions, l'initialisation du système avec le nombre de machines specifier et le processus servir qui consiste à consommer un temps à chaque service ce temps suit la loi exponentiel de paramètre µ qu'on va specifier plus tard

# %%
class Systeme(object):
    Nmbr_Q = 0 
    def __init__(self, env, nmbr_serveurs):
        self.env = env
        self.serveur = simpy.Resource(env, nmbr_serveurs)

    def servir(self, client,temps_service_unique):
        yield self.env.timeout(temps_service_unique)

# %% [markdown]
# un autre processus pour l'arrivée, l'attent de service et le départ de client

# %%
def client(env, nom, sys,temps_service_unique,temps_arrive):
    global Nmbr_Q
    Nmbr_Q= Nmbr_Q+1
    historique_de_systeme.append(Nmbr_Q)
    with sys.serveur.request() as request:
        yield request
        Nmbr_Q =Nmbr_Q - 1
        historique_de_systeme.append(Nmbr_Q)
        yield env.process(sys.servir(nom,temps_service_unique))
        print('%s quitte le système à %.2f.' % (nom, env.now))
        temps_de_sejour.append(env.now-temps_arrive)

# %% [markdown]
# Le dernier processus est le processus de création de nouveaux clients pendant que le système fonctionne le temps d'arriver des clients suit la loi de poisson de paramètre λ qu'on va specifier plus tard donc le temps d'inter arrive des clients suit la loi exponentielle de paramètre λ.

# %%
def setup(env, nmbr_serveurs):
    #creation de systeme
    systeme = Systeme(env, nmbr_serveurs)
    # creation de nouveaux clients pendant que le système fonctionne
    j =0
    expo_iterator=Exp(µ,SEED)
    while True:
        for i in Exp(λ,SEED):
            yield env.timeout(float("{0:.2f}".format(i)))
            temps_arrive = env.now
            j += 1
            nom ='client %d' % j
            temps_service_unique=next(expo_iterator)
            temps_de_service.append(temps_service_unique)
            print('%s arrive au system à %.2f.' % (nom, temps_arrive))
            env.process(client(env, 'client %d' % j, systeme,temps_service_unique,temps_arrive))

# %% [markdown]
# # Attention! ,il faut saisir les paramètres dans la cellule suivante

# %%
SEED = int(input("seed: >>>"))
λ = float(input("λ: >>>"))
µ = float(input("µ: >>>"))
# Out:
# seed: >>>6
# λ: >>>6
# µ: >>>1

# %% [markdown]
# Création d'un environnement et démarrage de processus setup(création de nouveaux clients pendant que le système fonctionne)

# %%
env = simpy.Environment()
env.process(setup(env, nmbr_serveurs))
# Out:
# <Process(setup) object at 0x258e354ee10>

# %% [markdown]
# Lancement de la simulation

# %%
env.run(until=temps_de_simulation)
# Out:
# client 1 arrive au system à 0.41.
# client 2 arrive au system à 0.45.
# client 3 arrive au system à 0.64.
# client 4 arrive au system à 0.67.
# client 2 quitte le système à 0.70.
# client 4 quitte le système à 0.85.
# client 5 arrive au system à 0.98.
# client 6 arrive au system à 1.11.
# client 7 arrive au system à 1.15.
# client 8 arrive au system à 1.33.
# client 7 quitte le système à 1.42.
# client 9 arrive au system à 1.68.
# client 3 quitte le système à 1.76.
# client 10 arrive au system à 1.81.
# client 11 arrive au system à 1.89.
# client 6 quitte le système à 1.91.
# client 12 arrive au system à 2.15.
# client 13 arrive au system à 2.19.
# client 14 arrive au system à 2.24.
# client 15 arrive au system à 2.30.
# client 11 quitte le système à 2.37.
# client 8 quitte le système à 2.39.
# client 16 arrive au system à 2.52.
# client 10 quitte le système à 2.58.
# client 17 arrive au system à 2.59.
# client 18 arrive au system à 2.61.
# client 13 quitte le système à 2.61.
# client 19 arrive au system à 2.82.
# client 20 arrive au system à 2.82.
# client 21 arrive au system à 2.86.
# client 5 quitte le système à 2.86.
# client 1 quitte le système à 2.90.
# client 14 quitte le système à 2.91.
# client 22 arrive au system à 2.93.
# client 15 quitte le système à 3.00.
# client 18 quitte le système à 3.04.
# client 20 quitte le système à 3.05.
# client 23 arrive au system à 3.17.
# client 21 quitte le système à 3.26.
# client 17 quitte le système à 3.32.
# client 24 arrive au system à 3.37.
# client 25 arrive au system à 3.65.
# client 22 quitte le système à 3.67.
# client 26 arrive au system à 3.68.
# client 27 arrive au system à 3.70.
# client 28 arrive au system à 3.72.
# client 29 arrive au system à 3.73.
# client 30 arrive au system à 3.76.
# client 9 quitte le système à 3.81.
# client 31 arrive au system à 3.87.
# client 12 quitte le système à 3.93.
# client 32 arrive au system à 4.07.
# client 33 arrive au system à 4.07.
# client 26 quitte le système à 4.09.
# client 16 quitte le système à 4.20.
# client 27 quitte le système à 4.20.
# client 29 quitte le système à 4.26.
# client 19 quitte le système à 4.26.
# client 28 quitte le système à 4.34.
# client 30 quitte le système à 4.43.
# client 33 quitte le système à 4.43.
# client 34 arrive au system à 4.54.
# client 35 arrive au system à 4.73.
# client 23 quitte le système à 4.77.
# client 36 arrive au system à 4.79.
# client 37 arrive au system à 4.84.
# client 24 quitte le système à 4.86.
# client 31 quitte le système à 4.94.
# client 38 arrive au system à 5.16.
# client 36 quitte le système à 5.20.
# client 37 quitte le système à 5.21.
# client 39 arrive au system à 5.37.
# client 40 arrive au system à 5.42.
# client 41 arrive au system à 5.44.
# client 25 quitte le système à 5.50.
# client 32 quitte le système à 5.52.
# client 41 quitte le système à 5.61.
# client 42 arrive au system à 5.67.
# client 40 quitte le système à 5.82.
# client 35 quitte le système à 5.91.
# client 43 arrive au system à 6.34.
# client 44 arrive au system à 6.43.
# client 39 quitte le système à 6.61.
# client 45 arrive au system à 6.62.
# client 46 arrive au system à 6.87.
# client 47 arrive au system à 6.91.
# client 44 quitte le système à 6.96.
# client 42 quitte le système à 7.03.
# client 48 arrive au system à 7.06.
# client 49 arrive au system à 7.07.
# client 38 quitte le système à 7.12.
# client 47 quitte le système à 7.26.
# client 49 quitte le système à 7.32.
# client 34 quitte le système à 7.35.
# client 50 arrive au system à 7.58.
# client 45 quitte le système à 7.74.
# client 51 arrive au system à 7.83.
# client 48 quitte le système à 8.00.
# client 52 arrive au system à 8.11.
# client 53 arrive au system à 8.16.
# client 54 arrive au system à 8.29.
# client 53 quitte le système à 8.45.
# client 55 arrive au system à 8.45.
# client 46 quitte le système à 8.45.
# client 56 arrive au system à 8.52.
# client 57 arrive au system à 8.58.
# client 58 arrive au system à 8.59.
# client 59 arrive au system à 9.05.
# client 60 arrive au system à 9.13.
# client 61 arrive au system à 9.21.
# client 54 quitte le système à 9.25.
# client 51 quitte le système à 9.34.
# client 55 quitte le système à 9.43.
# client 58 quitte le système à 9.49.
# client 62 arrive au system à 9.55.
# client 56 quitte le système à 9.66.
# client 57 quitte le système à 9.68.
# client 52 quitte le système à 9.80.
# client 61 quitte le système à 10.14.
# client 60 quitte le système à 10.16.
# client 43 quitte le système à 10.38.
# client 63 arrive au system à 10.44.
# client 64 arrive au system à 10.49.
# client 65 arrive au system à 10.50.
# client 66 arrive au system à 10.54.
# client 65 quitte le système à 10.58.
# client 50 quitte le système à 10.62.
# client 67 arrive au system à 10.65.
# client 68 arrive au system à 10.75.
# client 64 quitte le système à 10.81.
# client 66 quitte le système à 10.84.
# client 69 arrive au system à 10.92.
# client 70 arrive au system à 11.22.
# client 71 arrive au system à 11.28.
# client 67 quitte le système à 11.28.
# client 72 arrive au system à 11.35.
# client 68 quitte le système à 11.42.
# client 73 arrive au system à 11.45.
# client 74 arrive au system à 11.55.
# client 75 arrive au system à 11.75.
# client 71 quitte le système à 11.79.
# client 76 arrive au system à 11.79.
# client 62 quitte le système à 11.85.
# client 69 quitte le système à 11.94.
# client 77 arrive au system à 11.99.
# client 72 quitte le système à 12.18.
# client 59 quitte le système à 12.24.
# client 78 arrive au system à 12.42.
# client 79 arrive au system à 12.46.
# client 73 quitte le système à 12.47.
# client 76 quitte le système à 12.48.
# client 74 quitte le système à 12.51.
# client 80 arrive au system à 12.54.
# client 81 arrive au system à 12.56.
# client 82 arrive au system à 12.61.
# client 83 arrive au system à 12.74.
# client 79 quitte le système à 12.75.
# client 84 arrive au system à 12.99.
# client 85 arrive au system à 13.01.
# client 70 quitte le système à 13.06.
# client 81 quitte le système à 13.17.
# client 86 arrive au system à 13.19.
# client 80 quitte le système à 13.25.
# client 75 quitte le système à 13.38.
# client 82 quitte le système à 13.49.
# client 85 quitte le système à 13.63.
# client 87 arrive au system à 13.65.
# client 77 quitte le système à 13.65.
# client 88 arrive au system à 13.87.
# client 89 arrive au system à 13.92.
# client 90 arrive au system à 14.01.
# client 83 quitte le système à 14.04.
# client 91 arrive au system à 14.42.
# client 86 quitte le système à 14.72.
# client 84 quitte le système à 14.90.
# client 89 quitte le système à 15.00.
# client 78 quitte le système à 15.08.
# client 92 arrive au system à 15.15.
# client 93 arrive au system à 15.29.
# client 88 quitte le système à 15.37.
# client 90 quitte le système à 15.43.
# client 94 arrive au system à 15.56.
# client 95 arrive au system à 15.59.
# client 63 quitte le système à 15.77.
# client 95 quitte le système à 15.95.
# client 93 quitte le système à 16.21.
# client 96 arrive au system à 16.31.
# client 87 quitte le système à 16.43.
# client 97 arrive au system à 16.65.
# client 98 arrive au system à 16.80.
# client 99 arrive au system à 16.85.
# client 100 arrive au system à 17.02.
# client 94 quitte le système à 17.21.
# client 101 arrive au system à 17.35.
# client 102 arrive au system à 17.39.
# client 103 arrive au system à 17.43.
# client 91 quitte le système à 17.47.
# client 99 quitte le système à 17.52.
# client 104 arrive au system à 17.70.
# client 98 quitte le système à 17.73.
# client 102 quitte le système à 17.98.
# client 103 quitte le système à 18.22.
# client 105 arrive au system à 18.26.
# client 106 arrive au system à 18.35.
# client 107 arrive au system à 18.40.
# client 100 quitte le système à 18.47.
# client 108 arrive au system à 18.51.
# client 109 arrive au system à 18.60.
# client 110 arrive au system à 18.68.
# client 97 quitte le système à 18.72.
# client 111 arrive au system à 18.72.
# client 112 arrive au system à 18.74.
# client 113 arrive au system à 19.07.
# client 114 arrive au system à 19.16.
# client 106 quitte le système à 19.23.
# client 115 arrive au system à 19.28.
# client 101 quitte le système à 19.52.
# client 107 quitte le système à 19.52.
# client 92 quitte le système à 19.56.
# client 116 arrive au system à 19.56.
# client 117 arrive au system à 19.69.
# client 118 arrive au system à 19.81.
# client 104 quitte le système à 19.81.
# client 119 arrive au system à 19.90.
# client 120 arrive au system à 19.91.
# client 111 quitte le système à 20.03.
# client 109 quitte le système à 20.03.
# client 110 quitte le système à 20.06.
# client 112 quitte le système à 20.15.
# client 121 arrive au system à 20.17.
# client 108 quitte le système à 20.17.
# client 122 arrive au system à 20.23.
# client 123 arrive au system à 20.36.
# client 124 arrive au system à 20.55.
# client 125 arrive au system à 20.59.
# client 96 quitte le système à 20.60.
# client 114 quitte le système à 20.61.
# client 126 arrive au system à 20.63.
# client 115 quitte le système à 20.84.
# client 127 arrive au system à 20.94.
# client 128 arrive au system à 21.05.
# client 129 arrive au system à 21.15.
# client 130 arrive au system à 21.19.
# client 118 quitte le système à 21.30.
# client 120 quitte le système à 21.37.
# client 117 quitte le système à 21.38.
# client 119 quitte le système à 21.39.
# client 131 arrive au system à 21.48.
# client 132 arrive au system à 21.67.
# client 122 quitte le système à 21.73.
# client 133 arrive au system à 21.79.
# client 105 quitte le système à 21.82.
# client 116 quitte le système à 21.88.
# client 113 quitte le système à 22.02.
# client 125 quitte le système à 22.04.
# client 126 quitte le système à 22.10.
# client 123 quitte le système à 22.16.
# client 134 arrive au system à 22.25.
# client 130 quitte le système à 22.40.
# client 135 arrive au system à 22.42.
# client 136 arrive au system à 22.43.
# client 129 quitte le système à 22.69.
# client 137 arrive au system à 22.72.
# client 128 quitte le système à 22.73.
# client 138 arrive au system à 22.74.
# client 124 quitte le système à 22.88.
# client 121 quitte le système à 22.91.
# client 139 arrive au system à 23.11.
# client 140 arrive au system à 23.21.
# client 141 arrive au system à 23.42.
# client 133 quitte le système à 23.47.
# client 136 quitte le système à 23.55.
# client 132 quitte le système à 23.83.
# client 127 quitte le système à 23.86.
# client 138 quitte le système à 23.93.
# client 135 quitte le système à 23.94.
# client 131 quitte le système à 24.13.
# client 142 arrive au system à 24.14.
# client 140 quitte le système à 24.53.
# client 143 arrive au system à 24.78.
# client 144 arrive au system à 24.80.
# client 145 arrive au system à 24.80.
# client 146 arrive au system à 24.88.
# client 147 arrive au system à 25.06.
# client 141 quitte le système à 25.22.
# client 137 quitte le système à 25.29.
# client 148 arrive au system à 25.29.
# client 145 quitte le système à 25.31.
# client 144 quitte le système à 25.34.
# client 134 quitte le système à 25.61.
# client 146 quitte le système à 25.79.
# client 149 arrive au system à 25.99.
# client 150 arrive au system à 26.00.
# client 139 quitte le système à 26.10.
# client 150 quitte le système à 26.14.
# client 151 arrive au system à 26.28.
# client 147 quitte le système à 26.43.
# client 152 arrive au system à 26.71.
# client 153 arrive au system à 26.76.
# client 154 arrive au system à 26.88.
# client 148 quitte le système à 26.99.
# client 155 arrive au system à 27.18.
# client 156 arrive au system à 27.21.
# client 153 quitte le système à 27.32.
# client 157 arrive au system à 27.35.
# client 158 arrive au system à 27.44.
# client 159 arrive au system à 27.82.
# client 151 quitte le système à 27.95.
# client 154 quitte le système à 28.02.
# client 160 arrive au system à 28.15.
# client 161 arrive au system à 28.17.
# client 156 quitte le système à 28.18.
# client 142 quitte le système à 28.46.
# client 162 arrive au system à 28.52.
# client 143 quitte le système à 28.60.
# client 163 arrive au system à 28.61.
# client 164 arrive au system à 28.69.
# client 165 arrive au system à 28.69.
# client 166 arrive au system à 28.69.
# client 158 quitte le système à 29.01.
# client 167 arrive au system à 29.03.
# client 157 quitte le système à 29.04.
# client 161 quitte le système à 29.16.
# client 152 quitte le système à 29.30.
# client 168 arrive au system à 29.51.
# client 169 arrive au system à 29.65.
# client 155 quitte le système à 29.75.
# client 170 arrive au system à 29.81.
# client 163 quitte le système à 29.85.
# client 165 quitte le système à 29.86.
# client 166 quitte le système à 29.87.
# client 171 arrive au system à 29.90.
# client 172 arrive au system à 29.95.
# client 173 arrive au system à 30.03.
# client 164 quitte le système à 30.21.
# client 149 quitte le système à 30.21.
# client 174 arrive au system à 30.22.
# client 175 arrive au system à 30.33.
# client 176 arrive au system à 30.36.
# client 177 arrive au system à 30.49.
# client 178 arrive au system à 30.76.
# client 159 quitte le système à 30.88.
# client 179 arrive au system à 30.91.
# client 180 arrive au system à 30.97.
# client 160 quitte le système à 30.98.
# client 169 quitte le système à 31.02.
# client 181 arrive au system à 31.19.
# client 162 quitte le système à 31.25.
# client 182 arrive au system à 31.28.
# client 172 quitte le système à 31.29.
# client 171 quitte le système à 31.53.
# client 183 arrive au system à 31.64.
# client 184 arrive au system à 31.70.
# client 173 quitte le système à 31.71.
# client 185 arrive au system à 31.78.
# client 170 quitte le système à 31.83.
# client 176 quitte le système à 31.87.
# client 186 arrive au system à 31.88.
# client 167 quitte le système à 31.91.
# client 187 arrive au system à 31.95.
# client 175 quitte le système à 32.16.
# client 174 quitte le système à 32.42.
# client 188 arrive au system à 32.45.
# client 180 quitte le système à 32.50.
# client 177 quitte le système à 32.60.
# client 189 arrive au system à 32.72.
# client 190 arrive au system à 32.73.
# client 191 arrive au system à 32.78.
# client 179 quitte le système à 32.80.
# client 192 arrive au system à 32.91.
# client 182 quitte le système à 33.01.
# client 193 arrive au system à 33.02.
# client 194 arrive au system à 33.03.
# client 168 quitte le système à 33.10.
# client 184 quitte le système à 33.15.
# client 195 arrive au system à 33.38.
# client 196 arrive au system à 33.46.
# client 178 quitte le système à 33.49.
# client 185 quitte le système à 33.51.
# client 197 arrive au system à 33.57.
# client 187 quitte le système à 33.59.
# client 190 quitte le système à 33.63.
# client 186 quitte le système à 33.72.
# client 181 quitte le système à 33.76.
# client 198 arrive au system à 33.76.
# client 199 arrive au system à 33.79.
# client 191 quitte le système à 33.91.
# client 200 arrive au system à 33.94.
# client 194 quitte le système à 33.97.
# client 193 quitte le système à 34.41.
# client 201 arrive au system à 34.49.
# client 192 quitte le système à 34.53.
# client 202 arrive au system à 34.70.
# client 203 arrive au system à 34.73.
# client 183 quitte le système à 34.76.
# client 196 quitte le système à 34.86.
# client 199 quitte le système à 35.06.
# client 204 arrive au system à 35.07.
# client 189 quitte le système à 35.10.
# client 197 quitte le système à 35.19.
# client 205 arrive au system à 35.36.
# client 206 arrive au system à 35.51.
# client 207 arrive au system à 35.66.
# client 208 arrive au system à 35.75.
# client 198 quitte le système à 35.87.
# client 209 arrive au system à 35.93.
# client 200 quitte le système à 35.98.
# client 203 quitte le système à 36.03.
# client 195 quitte le système à 36.06.
# client 202 quitte le système à 36.45.
# client 188 quitte le système à 36.51.
# client 210 arrive au system à 36.56.
# client 211 arrive au system à 36.63.
# client 212 arrive au system à 36.64.
# client 206 quitte le système à 36.93.
# client 213 arrive au system à 36.96.
# client 208 quitte le système à 37.04.
# client 214 arrive au system à 37.32.
# client 207 quitte le système à 37.32.
# client 215 arrive au system à 37.42.
# client 216 arrive au system à 37.57.
# client 217 arrive au system à 37.58.
# client 218 arrive au system à 37.63.
# client 219 arrive au system à 37.67.
# client 205 quitte le système à 37.75.
# client 211 quitte le système à 37.75.
# client 220 arrive au system à 37.82.
# client 212 quitte le système à 37.83.
# client 209 quitte le système à 38.00.
# client 221 arrive au system à 38.04.
# client 204 quitte le système à 38.04.
# client 222 arrive au system à 38.27.
# client 201 quitte le système à 38.40.
# client 217 quitte le système à 38.45.
# client 223 arrive au system à 38.54.
# client 215 quitte le système à 38.58.
# client 224 arrive au system à 38.64.
# client 225 arrive au system à 38.73.
# client 218 quitte le système à 38.75.
# client 219 quitte le système à 38.80.
# client 216 quitte le système à 38.92.
# client 226 arrive au system à 39.12.
# client 227 arrive au system à 39.25.
# client 228 arrive au system à 39.30.
# client 220 quitte le système à 39.63.
# client 229 arrive au system à 39.68.
# client 213 quitte le système à 39.70.
# client 230 arrive au system à 39.73.
# client 214 quitte le système à 39.97.
# client 231 arrive au system à 40.08.
# client 221 quitte le système à 40.15.
# client 232 arrive au system à 40.26.
# client 233 arrive au system à 40.28.
# client 222 quitte le système à 40.29.
# client 224 quitte le système à 40.30.
# client 225 quitte le système à 40.52.
# client 234 arrive au system à 40.58.
# client 228 quitte le système à 40.60.
# client 210 quitte le système à 40.84.
# client 230 quitte le système à 40.93.
# client 227 quitte le système à 41.05.
# client 235 arrive au system à 41.05.
# client 236 arrive au system à 41.11.
# client 233 quitte le système à 41.17.
# client 237 arrive au system à 41.18.
# client 223 quitte le système à 41.24.
# client 238 arrive au system à 41.93.
# client 239 arrive au system à 41.98.
# client 232 quitte le système à 42.00.
# client 240 arrive au system à 42.08.
# client 236 quitte le système à 42.34.
# client 241 arrive au system à 42.47.
# client 226 quitte le système à 42.49.
# client 237 quitte le système à 42.77.
# client 229 quitte le système à 42.78.
# client 242 arrive au system à 42.81.
# client 231 quitte le système à 42.93.
# client 243 arrive au system à 42.95.
# client 234 quitte le système à 42.96.
# client 239 quitte le système à 43.09.
# client 244 arrive au system à 43.13.
# client 245 arrive au system à 43.16.
# client 240 quitte le système à 43.39.
# client 246 arrive au system à 43.59.
# client 247 arrive au system à 43.65.
# client 248 arrive au system à 43.80.
# client 243 quitte le système à 43.90.
# client 249 arrive au system à 43.91.
# client 235 quitte le système à 44.07.
# client 250 arrive au system à 44.08.
# client 245 quitte le système à 44.11.
# client 244 quitte le système à 44.45.
# client 247 quitte le système à 44.48.
# client 251 arrive au system à 44.69.
# client 252 arrive au system à 44.78.
# client 253 arrive au system à 44.79.
# client 254 arrive au system à 44.88.
# client 242 quitte le système à 44.97.
# client 255 arrive au system à 45.01.
# client 249 quitte le système à 45.13.
# client 241 quitte le système à 45.25.
# client 256 arrive au system à 45.31.
# client 257 arrive au system à 45.33.
# client 248 quitte le système à 45.35.
# client 258 arrive au system à 45.36.
# client 259 arrive au system à 45.41.
# client 253 quitte le système à 45.41.
# client 260 arrive au system à 45.55.
# client 252 quitte le système à 45.82.
# client 254 quitte le système à 45.92.
# client 250 quitte le système à 46.01.
# client 257 quitte le système à 46.13.
# client 261 arrive au system à 46.20.
# client 262 arrive au system à 46.27.
# client 258 quitte le système à 46.33.
# client 263 arrive au system à 46.34.
# client 264 arrive au system à 46.36.
# client 265 arrive au system à 46.44.
# client 266 arrive au system à 46.44.
# client 267 arrive au system à 46.47.
# client 268 arrive au system à 46.54.
# client 269 arrive au system à 46.54.
# client 270 arrive au system à 46.61.
# client 255 quitte le système à 46.61.
# client 259 quitte le système à 46.64.
# client 246 quitte le système à 46.68.
# client 271 arrive au system à 46.73.
# client 272 arrive au system à 46.78.
# client 273 arrive au system à 46.79.
# client 274 arrive au system à 46.80.
# client 275 arrive au system à 46.87.
# client 238 quitte le système à 46.96.
# client 276 arrive au system à 46.97.
# client 277 arrive au system à 47.04.
# client 278 arrive au system à 47.06.
# client 262 quitte le système à 47.11.
# client 279 arrive au system à 47.14.
# client 264 quitte le système à 47.22.
# client 280 arrive au system à 47.27.
# client 281 arrive au system à 47.30.
# client 282 arrive au system à 47.30.
# client 263 quitte le système à 47.35.
# client 266 quitte le système à 47.38.
# client 260 quitte le système à 47.42.
# client 267 quitte le système à 47.57.
# client 269 quitte le système à 47.59.
# client 283 arrive au system à 47.60.
# client 265 quitte le système à 47.71.
# client 256 quitte le système à 47.71.
# client 268 quitte le système à 47.82.
# client 284 arrive au system à 47.86.
# client 285 arrive au system à 47.90.
# client 286 arrive au system à 47.90.
# client 273 quitte le système à 47.90.
# client 274 quitte le système à 47.99.
# client 270 quitte le système à 47.99.
# client 287 arrive au system à 48.01.
# client 272 quitte le système à 48.04.
# client 288 arrive au system à 48.09.
# client 271 quitte le système à 48.43.
# client 275 quitte le système à 48.43.
# client 277 quitte le système à 48.46.
# client 278 quitte le système à 48.57.
# client 276 quitte le système à 48.60.
# client 282 quitte le système à 48.62.
# client 281 quitte le système à 48.76.
# client 251 quitte le système à 48.77.
# client 289 arrive au system à 48.78.
# client 290 arrive au system à 48.85.
# client 279 quitte le système à 48.89.
# client 286 quitte le système à 48.91.
# client 291 arrive au system à 48.96.
# client 285 quitte le système à 49.02.
# client 292 arrive au system à 49.13.
# client 293 arrive au system à 49.18.
# client 280 quitte le système à 49.22.
# client 294 arrive au system à 49.32.
# client 288 quitte le système à 49.51.
# client 287 quitte le système à 49.57.
# client 295 arrive au system à 49.70.
# client 296 arrive au system à 49.78.
# client 297 arrive au system à 49.86.
# client 298 arrive au system à 49.87.
# client 290 quitte le système à 49.93.
# client 299 arrive au system à 50.12.
# client 291 quitte le système à 50.25.
# client 284 quitte le système à 50.30.
# client 300 arrive au system à 50.34.
# client 283 quitte le système à 50.42.
# client 301 arrive au system à 50.51.
# client 293 quitte le système à 50.53.
# client 261 quitte le système à 50.53.
# client 302 arrive au system à 50.55.
# client 303 arrive au system à 50.62.
# client 304 arrive au system à 50.67.
# client 305 arrive au system à 50.72.
# client 292 quitte le système à 50.93.
# client 298 quitte le système à 50.96.
# client 296 quitte le système à 51.01.
# client 297 quitte le système à 51.04.
# client 306 arrive au system à 51.09.
# client 294 quitte le système à 51.14.
# client 307 arrive au system à 51.18.
# client 302 quitte le système à 51.37.
# client 308 arrive au system à 51.47.
# client 309 arrive au system à 51.69.
# client 310 arrive au system à 51.74.
# client 303 quitte le système à 51.77.
# client 311 arrive au system à 51.86.
# client 312 arrive au system à 51.86.
# client 301 quitte le système à 52.09.
# client 304 quitte le système à 52.10.
# client 313 arrive au system à 52.29.
# client 300 quitte le système à 52.33.
# client 314 arrive au system à 52.39.
# client 305 quitte le système à 52.40.
# client 299 quitte le système à 52.44.
# client 315 arrive au system à 52.49.
# client 295 quitte le système à 52.72.
# client 316 arrive au system à 52.80.
# client 317 arrive au system à 52.89.
# client 307 quitte le système à 52.90.
# client 310 quitte le système à 53.03.
# client 312 quitte le système à 53.05.
# client 318 arrive au system à 53.13.
# client 319 arrive au system à 53.30.
# client 320 arrive au system à 53.34.
# client 289 quitte le système à 53.37.
# client 321 arrive au system à 53.59.
# client 311 quitte le système à 53.60.
# client 322 arrive au system à 53.70.
# client 323 arrive au system à 53.73.
# client 309 quitte le système à 53.74.
# client 314 quitte le système à 53.95.
# client 324 arrive au system à 54.00.
# client 308 quitte le système à 54.13.
# client 315 quitte le système à 54.22.
# client 306 quitte le système à 54.31.
# client 317 quitte le système à 54.49.
# client 320 quitte le système à 54.56.
# client 325 arrive au system à 54.72.
# client 326 arrive au system à 54.97.
# client 327 arrive au system à 54.97.
# client 328 arrive au system à 55.03.
# client 329 arrive au system à 55.04.
# client 330 arrive au system à 55.08.
# client 331 arrive au system à 55.11.
# client 332 arrive au system à 55.14.
# client 322 quitte le système à 55.19.
# client 319 quitte le système à 55.22.
# client 323 quitte le système à 55.35.
# client 333 arrive au system à 55.46.
# client 334 arrive au system à 55.53.
# client 318 quitte le système à 55.59.
# client 316 quitte le système à 55.61.
# client 327 quitte le système à 55.63.
# client 313 quitte le système à 55.64.
# client 329 quitte le système à 55.73.
# client 335 arrive au system à 55.77.
# client 336 arrive au system à 55.82.
# client 328 quitte le système à 55.97.
# client 321 quitte le système à 55.98.
# client 330 quitte le système à 55.99.
# client 337 arrive au system à 56.14.
# client 332 quitte le système à 56.16.
# client 331 quitte le système à 56.17.
# client 338 arrive au system à 56.18.
# client 334 quitte le système à 56.59.
# client 339 arrive au system à 56.78.
# client 340 arrive au system à 56.78.
# client 324 quitte le système à 56.82.
# client 336 quitte le système à 56.88.
# client 341 arrive au system à 56.91.
# client 342 arrive au system à 56.95.
# client 326 quitte le système à 57.07.
# client 343 arrive au system à 57.12.
# client 338 quitte le système à 57.13.
# client 344 arrive au system à 57.14.
# client 340 quitte le système à 57.15.
# client 345 arrive au system à 57.40.
# client 346 arrive au system à 57.56.
# client 347 arrive au system à 57.57.
# client 335 quitte le système à 57.61.
# client 348 arrive au system à 57.78.
# client 342 quitte le système à 57.87.
# client 341 quitte le système à 57.90.
# client 333 quitte le système à 57.93.
# client 349 arrive au system à 57.96.
# client 344 quitte le système à 58.00.
# client 350 arrive au system à 58.62.
# client 351 arrive au system à 58.63.
# client 337 quitte le système à 58.71.
# client 347 quitte le système à 58.79.
# client 343 quitte le système à 58.91.
# client 352 arrive au system à 58.91.
# client 346 quitte le système à 58.96.
# client 353 arrive au system à 59.02.
# client 354 arrive au system à 59.09.
# client 355 arrive au system à 59.29.
# client 356 arrive au system à 59.34.
# client 357 arrive au system à 59.39.
# client 345 quitte le système à 59.48.
# client 351 quitte le système à 59.54.
# client 325 quitte le système à 59.66.
# client 358 arrive au system à 59.89.
# client 359 arrive au system à 59.91.
# client 360 arrive au system à 59.92.
# client 349 quitte le système à 60.00.
# client 348 quitte le système à 60.08.
# client 361 arrive au system à 60.09.
# client 362 arrive au system à 60.27.
# client 353 quitte le système à 60.33.
# client 363 arrive au system à 60.35.
# client 364 arrive au system à 60.38.
# client 365 arrive au system à 60.39.
# client 354 quitte le système à 60.40.
# client 366 arrive au system à 60.58.
# client 356 quitte le système à 60.63.
# client 339 quitte le système à 60.66.
# client 357 quitte le système à 60.73.
# client 359 quitte le système à 60.78.
# client 360 quitte le système à 60.79.
# client 367 arrive au system à 60.95.
# client 368 arrive au system à 61.03.
# client 369 arrive au system à 61.13.
# client 352 quitte le système à 61.23.
# client 355 quitte le système à 61.28.
# client 370 arrive au system à 61.31.
# client 364 quitte le système à 61.48.
# client 365 quitte le système à 61.52.
# client 371 arrive au system à 61.52.
# client 372 arrive au system à 61.56.
# client 363 quitte le système à 61.69.
# client 373 arrive au system à 61.77.
# client 374 arrive au system à 61.79.
# client 361 quitte le système à 61.83.
# client 362 quitte le système à 61.90.
# client 375 arrive au system à 62.03.
# client 376 arrive au system à 62.06.
# client 377 arrive au system à 62.08.
# client 368 quitte le système à 62.33.
# client 369 quitte le système à 62.51.
# client 378 arrive au system à 62.52.
# client 379 arrive au system à 62.61.
# client 366 quitte le système à 62.68.
# client 380 arrive au system à 62.70.
# client 372 quitte le système à 62.91.
# client 381 arrive au system à 62.93.
# client 350 quitte le système à 62.94.
# client 382 arrive au system à 62.96.
# client 374 quitte le système à 63.04.
# client 383 arrive au system à 63.27.
# client 384 arrive au system à 63.29.
# client 370 quitte le système à 63.38.
# client 385 arrive au system à 63.38.
# client 386 arrive au system à 63.45.
# client 387 arrive au system à 63.48.
# client 388 arrive au system à 63.50.
# client 376 quitte le système à 63.56.
# client 358 quitte le système à 63.61.
# client 377 quitte le système à 63.68.
# client 371 quitte le système à 63.79.
# client 367 quitte le système à 63.90.
# client 389 arrive au system à 64.11.
# client 373 quitte le système à 64.15.
# client 390 arrive au system à 64.16.
# client 379 quitte le système à 64.21.
# client 382 quitte le système à 64.30.
# client 391 arrive au system à 64.34.
# client 380 quitte le système à 64.36.
# client 384 quitte le système à 64.40.
# client 392 arrive au system à 64.41.
# client 375 quitte le système à 64.45.
# client 393 arrive au system à 64.55.
# client 394 arrive au system à 64.56.
# client 387 quitte le système à 64.61.
# client 388 quitte le système à 64.75.
# client 386 quitte le système à 64.79.
# client 395 arrive au system à 64.89.
# client 385 quitte le système à 64.90.
# client 396 arrive au system à 64.94.
# client 397 arrive au system à 65.01.
# client 398 arrive au system à 65.06.
# client 390 quitte le système à 65.08.
# client 381 quitte le système à 65.31.
# client 399 arrive au system à 65.34.
# client 400 arrive au system à 65.40.
# client 401 arrive au system à 65.41.
# client 392 quitte le système à 65.49.
# client 402 arrive au system à 65.50.
# client 394 quitte le système à 65.53.
# client 403 arrive au system à 66.00.
# client 391 quitte le système à 66.00.
# client 383 quitte le système à 66.09.
# client 404 arrive au system à 66.10.
# client 405 arrive au system à 66.10.
# client 406 arrive au system à 66.12.
# client 393 quitte le système à 66.16.
# client 378 quitte le système à 66.23.
# client 396 quitte le système à 66.28.
# client 407 arrive au system à 66.41.
# client 408 arrive au system à 66.43.
# client 398 quitte le système à 66.47.
# client 401 quitte le système à 66.50.
# client 397 quitte le système à 66.54.
# client 409 arrive au system à 66.55.
# client 410 arrive au system à 66.63.
# client 400 quitte le système à 66.66.
# client 411 arrive au system à 66.86.
# client 402 quitte le système à 67.05.
# client 405 quitte le système à 67.07.
# client 406 quitte le système à 67.16.
# client 412 arrive au system à 67.22.
# client 404 quitte le système à 67.27.
# client 413 arrive au system à 67.27.
# client 408 quitte le système à 67.36.
# client 395 quitte le système à 67.49.
# client 414 arrive au system à 67.63.
# client 415 arrive au system à 67.65.
# client 416 arrive au system à 67.72.
# client 417 arrive au system à 67.74.
# client 418 arrive au system à 67.87.
# client 419 arrive au system à 67.88.
# client 399 quitte le système à 67.92.
# client 420 arrive au system à 67.97.
# client 410 quitte le système à 67.99.
# client 409 quitte le système à 68.09.
# client 421 arrive au system à 68.18.
# client 413 quitte le système à 68.37.
# client 389 quitte le système à 68.42.
# client 415 quitte le système à 68.56.
# client 422 arrive au system à 68.78.
# client 423 arrive au system à 68.82.
# client 424 arrive au system à 68.85.
# client 407 quitte le système à 68.89.
# client 416 quitte le système à 69.01.
# client 425 arrive au system à 69.01.
# client 417 quitte le système à 69.03.
# client 419 quitte le système à 69.07.
# client 426 arrive au system à 69.21.
# client 411 quitte le système à 69.32.
# client 427 arrive au system à 69.40.
# client 403 quitte le système à 69.52.
# client 428 arrive au system à 69.62.
# client 420 quitte le système à 69.63.
# client 418 quitte le système à 69.76.
# client 423 quitte le système à 69.84.
# client 429 arrive au system à 69.88.
# client 424 quitte le système à 69.92.
# client 430 arrive au system à 69.94.
# client 412 quitte le système à 70.13.
# client 431 arrive au system à 70.13.
# client 432 arrive au system à 70.14.
# client 433 arrive au system à 70.39.
# client 434 arrive au system à 70.48.
# client 414 quitte le système à 70.51.
# client 421 quitte le système à 70.57.
# client 435 arrive au system à 70.58.
# client 436 arrive au system à 70.80.
# client 425 quitte le système à 70.82.
# client 426 quitte le système à 71.15.
# client 430 quitte le système à 71.19.
# client 432 quitte le système à 71.24.
# client 427 quitte le système à 71.28.
# client 437 arrive au system à 71.46.
# client 438 arrive au system à 71.61.
# client 428 quitte le système à 71.82.
# client 434 quitte le système à 71.83.
# client 439 arrive au system à 71.95.
# client 440 arrive au system à 71.97.
# client 429 quitte le système à 72.14.
# client 431 quitte le système à 72.30.
# client 441 arrive au system à 72.37.
# client 435 quitte le système à 72.42.
# client 442 arrive au system à 72.57.
# client 433 quitte le système à 72.76.
# client 440 quitte le système à 72.87.
# client 443 arrive au system à 72.95.
# client 436 quitte le système à 73.14.
# client 422 quitte le système à 73.14.
# client 438 quitte le système à 73.20.
# client 444 arrive au system à 73.35.
# client 445 arrive au system à 73.46.
# client 446 arrive au system à 73.46.
# client 447 arrive au system à 73.47.
# client 448 arrive au system à 73.54.
# client 449 arrive au system à 73.65.
# client 450 arrive au system à 73.83.
# client 451 arrive au system à 73.92.
# client 452 arrive au system à 73.94.
# client 442 quitte le système à 74.34.
# client 453 arrive au system à 74.35.
# client 439 quitte le système à 74.46.
# client 446 quitte le système à 74.46.
# client 454 arrive au system à 74.50.
# client 447 quitte le système à 74.53.
# client 455 arrive au system à 74.54.
# client 448 quitte le système à 74.95.
# client 445 quitte le système à 75.01.
# client 456 arrive au system à 75.05.
# client 441 quitte le système à 75.29.
# client 457 arrive au system à 75.36.
# client 443 quitte le système à 75.45.
# client 452 quitte le système à 75.54.
# client 458 arrive au system à 75.55.
# client 449 quitte le système à 75.59.
# client 459 arrive au system à 75.64.
# client 444 quitte le système à 75.73.
# client 451 quitte le système à 75.84.
# client 455 quitte le système à 75.97.
# client 460 arrive au system à 76.05.
# client 461 arrive au system à 76.06.
# client 450 quitte le système à 76.07.
# client 462 arrive au system à 76.10.
# client 437 quitte le système à 76.10.
# client 463 arrive au system à 76.28.
# client 454 quitte le système à 76.47.
# client 459 quitte le système à 76.65.
# client 461 quitte le système à 76.72.
# client 462 quitte le système à 76.93.
# client 458 quitte le système à 77.20.
# client 464 arrive au system à 77.47.
# client 465 arrive au system à 77.51.
# client 466 arrive au system à 77.55.
# client 467 arrive au system à 77.69.
# client 457 quitte le système à 77.86.
# client 453 quitte le système à 77.99.
# client 463 quitte le système à 78.01.
# client 465 quitte le système à 78.08.
# client 468 arrive au system à 78.11.
# client 466 quitte le système à 78.22.
# client 469 arrive au system à 78.50.
# client 470 arrive au system à 78.53.
# client 467 quitte le système à 78.83.
# client 456 quitte le système à 78.92.
# client 460 quitte le système à 78.92.
# client 470 quitte le système à 78.99.
# client 471 arrive au system à 79.02.
# client 472 arrive au system à 79.33.
# client 473 arrive au system à 79.44.
# client 474 arrive au system à 79.47.
# client 475 arrive au system à 79.51.
# client 476 arrive au system à 79.56.
# client 477 arrive au system à 79.72.
# client 478 arrive au system à 79.82.
# client 473 quitte le système à 80.10.
# client 479 arrive au system à 80.11.
# client 480 arrive au system à 80.14.
# client 481 arrive au system à 80.29.
# client 482 arrive au system à 80.30.
# client 474 quitte le système à 80.30.
# client 475 quitte le système à 80.52.
# client 468 quitte le système à 80.62.
# client 483 arrive au system à 80.70.
# client 476 quitte le système à 80.79.
# client 469 quitte le système à 80.87.
# client 484 arrive au system à 81.17.
# client 472 quitte le système à 81.18.
# client 480 quitte le système à 81.36.
# client 478 quitte le système à 81.42.
# client 485 arrive au system à 81.42.
# client 482 quitte le système à 81.50.
# client 477 quitte le système à 81.57.
# client 486 arrive au system à 81.62.
# client 487 arrive au system à 81.68.
# client 488 arrive au system à 81.83.
# client 489 arrive au system à 81.97.
# client 471 quitte le système à 81.97.
# client 490 arrive au system à 82.13.
# client 491 arrive au system à 82.16.
# client 481 quitte le système à 82.25.
# client 479 quitte le système à 82.58.
# client 492 arrive au system à 82.86.
# client 487 quitte le système à 82.95.
# client 493 arrive au system à 83.06.
# client 494 arrive au system à 83.16.
# client 486 quitte le système à 83.44.
# client 485 quitte le système à 83.47.
# client 495 arrive au system à 83.65.
# client 496 arrive au system à 83.65.
# client 497 arrive au system à 83.66.
# client 488 quitte le système à 83.85.
# client 483 quitte le système à 83.90.
# client 491 quitte le système à 84.05.
# client 498 arrive au system à 84.29.
# client 489 quitte le système à 84.29.
# client 499 arrive au system à 84.31.
# client 484 quitte le système à 84.38.
# client 490 quitte le système à 84.41.
# client 496 quitte le système à 84.42.
# client 497 quitte le système à 84.47.
# client 500 arrive au system à 84.58.
# client 464 quitte le système à 84.59.
# client 499 quitte le système à 84.74.
# client 494 quitte le système à 84.88.
# client 501 arrive au system à 84.94.
# client 502 arrive au system à 85.04.
# client 503 arrive au system à 85.07.
# client 504 arrive au system à 85.15.
# client 493 quitte le système à 85.27.
# client 505 arrive au system à 85.35.
# client 506 arrive au system à 85.66.
# client 507 arrive au system à 85.78.
# client 502 quitte le système à 85.87.
# client 508 arrive au system à 85.90.
# client 503 quitte le système à 86.02.
# client 509 arrive au system à 86.03.
# client 510 arrive au system à 86.11.
# client 511 arrive au system à 86.28.
# client 512 arrive au system à 86.35.
# client 500 quitte le système à 86.37.
# client 504 quitte le système à 86.50.
# client 513 arrive au system à 86.71.
# client 514 arrive au system à 87.03.
# client 501 quitte le système à 87.10.
# client 515 arrive au system à 87.19.
# client 495 quitte le système à 87.29.
# client 516 arrive au system à 87.40.
# client 517 arrive au system à 87.45.
# client 518 arrive au system à 87.46.
# client 519 arrive au system à 87.47.
# client 520 arrive au system à 87.54.
# client 505 quitte le système à 87.58.
# client 521 arrive au system à 87.63.
# client 507 quitte le système à 87.80.
# client 522 arrive au system à 87.94.
# client 508 quitte le système à 88.00.
# client 523 arrive au system à 88.08.
# client 524 arrive au system à 88.09.
# client 525 arrive au system à 88.09.
# client 492 quitte le système à 88.09.
# client 510 quitte le système à 88.25.
# client 498 quitte le système à 88.28.
# client 526 arrive au system à 88.32.
# client 509 quitte le système à 88.33.
# client 506 quitte le système à 88.34.
# client 512 quitte le système à 88.53.
# client 527 arrive au system à 88.57.
# client 528 arrive au system à 88.63.
# client 529 arrive au system à 88.72.
# client 517 quitte le système à 88.85.
# client 530 arrive au system à 88.87.
# client 518 quitte le système à 88.94.
# client 511 quitte le système à 89.00.
# client 531 arrive au system à 89.01.
# client 519 quitte le système à 89.01.
# client 532 arrive au system à 89.02.
# client 533 arrive au system à 89.28.
# client 515 quitte le système à 89.28.
# client 534 arrive au system à 89.35.
# client 520 quitte le système à 89.40.
# client 535 arrive au system à 89.49.
# client 536 arrive au system à 89.52.
# client 521 quitte le système à 89.54.
# client 524 quitte le système à 89.58.
# client 537 arrive au system à 89.58.
# client 525 quitte le système à 89.58.
# client 516 quitte le système à 89.61.
# client 538 arrive au system à 89.65.
# client 539 arrive au system à 89.69.
# client 540 arrive au system à 89.74.
# client 541 arrive au system à 90.18.
# client 514 quitte le système à 90.20.
# client 523 quitte le système à 90.27.
# client 513 quitte le système à 90.43.
# client 528 quitte le système à 90.56.
# client 529 quitte le système à 90.79.
# client 542 arrive au system à 90.80.
# client 532 quitte le système à 90.87.
# client 526 quitte le système à 90.96.
# client 543 arrive au system à 91.02.
# client 527 quitte le système à 91.11.
# client 522 quitte le système à 91.13.
# client 536 quitte le système à 91.33.
# client 544 arrive au system à 91.34.
# client 545 arrive au system à 91.35.
# client 530 quitte le système à 91.35.
# client 534 quitte le système à 91.39.
# client 531 quitte le système à 91.40.
# client 546 arrive au system à 91.53.
# client 547 arrive au system à 91.57.
# client 548 arrive au system à 91.58.
# client 549 arrive au system à 91.61.
# client 539 quitte le système à 91.64.
# client 537 quitte le système à 91.71.
# client 540 quitte le système à 91.72.
# client 538 quitte le système à 91.75.
# client 550 arrive au system à 91.80.
# client 551 arrive au system à 91.82.
# client 535 quitte le système à 91.95.
# client 545 quitte le système à 92.02.
# client 552 arrive au system à 92.12.
# client 553 arrive au system à 92.17.
# client 554 arrive au system à 92.24.
# client 533 quitte le système à 92.42.
# client 555 arrive au system à 92.51.
# client 556 arrive au system à 92.52.
# client 557 arrive au system à 92.53.
# client 547 quitte le système à 92.64.
# client 548 quitte le système à 92.72.
# client 549 quitte le système à 92.92.
# client 558 arrive au system à 93.03.
# client 543 quitte le système à 93.04.
# client 546 quitte le système à 93.07.
# client 559 arrive au system à 93.12.
# client 551 quitte le système à 93.18.
# client 560 arrive au system à 93.25.
# client 561 arrive au system à 93.40.
# client 553 quitte le système à 93.47.
# client 562 arrive au system à 93.55.
# client 544 quitte le système à 93.66.
# client 563 arrive au system à 93.81.
# client 564 arrive au system à 93.88.
# client 554 quitte le système à 93.90.
# client 565 arrive au system à 93.93.
# client 556 quitte le système à 93.95.
# client 557 quitte le système à 94.01.
# client 550 quitte le système à 94.06.
# client 566 arrive au system à 94.24.
# client 541 quitte le système à 94.27.
# client 567 arrive au system à 94.32.
# client 568 arrive au system à 94.34.
# client 569 arrive au system à 94.42.
# client 559 quitte le système à 94.59.
# client 570 arrive au system à 94.89.
# client 552 quitte le système à 94.90.
# client 571 arrive au system à 94.95.
# client 560 quitte le système à 95.02.
# client 555 quitte le système à 95.26.
# client 542 quitte le système à 95.40.
# client 561 quitte le système à 95.48.
# client 572 arrive au system à 95.50.
# client 573 arrive au system à 95.56.
# client 564 quitte le système à 95.68.
# client 565 quitte le système à 95.72.
# client 574 arrive au system à 95.77.
# client 562 quitte le système à 95.81.
# client 568 quitte le système à 95.82.
# client 575 arrive au system à 95.86.
# client 576 arrive au system à 95.86.
# client 577 arrive au system à 95.88.
# client 567 quitte le système à 96.15.
# client 578 arrive au system à 96.17.
# client 569 quitte le système à 96.26.
# client 579 arrive au system à 96.49.
# client 571 quitte le système à 96.51.
# client 563 quitte le système à 96.58.
# client 580 arrive au system à 96.63.
# client 581 arrive au system à 96.64.
# client 582 arrive au system à 96.78.
# client 583 arrive au system à 96.81.
# client 584 arrive au system à 96.84.
# client 573 quitte le système à 96.84.
# client 585 arrive au system à 96.89.
# client 558 quitte le système à 97.03.
# client 576 quitte le système à 97.04.
# client 586 arrive au system à 97.13.
# client 577 quitte le système à 97.13.
# client 587 arrive au system à 97.26.
# client 566 quitte le système à 97.35.
# client 575 quitte le système à 97.38.
# client 588 arrive au system à 97.75.
# client 574 quitte le système à 97.82.
# client 581 quitte le système à 97.85.
# client 589 arrive au system à 97.96.
# client 590 arrive au system à 97.97.
# client 591 arrive au system à 98.00.
# client 580 quitte le système à 98.21.
# client 592 arrive au system à 98.22.
# client 593 arrive au system à 98.26.
# client 594 arrive au system à 98.28.
# client 595 arrive au system à 98.33.
# client 596 arrive au system à 98.35.
# client 583 quitte le système à 98.39.
# client 584 quitte le système à 98.59.
# client 597 arrive au system à 98.59.
# client 598 arrive au system à 98.61.
# client 570 quitte le système à 98.66.
# client 582 quitte le système à 98.68.
# client 599 arrive au system à 98.83.
# client 578 quitte le système à 98.87.
# client 585 quitte le système à 98.89.
# client 600 arrive au system à 98.92.
# client 601 arrive au system à 98.95.
# client 602 arrive au system à 99.13.
# client 603 arrive au system à 99.16.
# client 579 quitte le système à 99.27.
# client 590 quitte le système à 99.32.
# client 587 quitte le système à 99.43.
# client 591 quitte le système à 99.49.
# client 572 quitte le système à 99.54.
# client 604 arrive au system à 99.66.
# client 594 quitte le système à 99.68.
# client 593 quitte le système à 99.74.
# client 596 quitte le système à 99.85.
# client 595 quitte le système à 99.97.
# client 605 arrive au system à 99.97.

# %% [markdown]
# 3èmè partie : Comparaison des carectiristiques de systeme sur le plan theorique avec les resultats obtenue d'apres la simulation que j'ai fait

# %% [markdown]
# # Remarque :
# pour le calcul des caractéristiques du système sur le plan théorique je vais utiliser le code suivant de monsieur ZOUAHI Hafidh

# %%
from math import factorial
class QueuingSystem:
    def __init__(self, λ, µ, s, l=None):
        self.s = s
        self.λ = λ
        self.µ = µ
        self.ρ = (λ/(s*µ))
        self.l = None
        if l is not None:
            self.l = l
        if l is None:
            self.p_zero = (sum((1/factorial(k))*(λ/µ)**k for k in range(s))\
                           + (1/factorial(s))*((λ/µ)**s)*((s*µ)/(s*µ - λ))\
                          )**(-1)
        else:
            u = λ / µ
            if u == s:
                self.p_zero = (sum(s**i/factorial(i) for i in range(s))\
                               + (s**s/factorial(s))*(l - s + 1)
                              )**(-1)
            else:
                self.p_zero = (sum(u**i/factorial(i) for i in range(s))\
                               + ((u**s)/factorial(s))*((1 - (u/s)**(l-s+1))/(1-u/s))
                              )**(-1)
    
    def isStationary(self):
        return self.ρ < 1
    
    def computePi(self, i):
        u = self.λ / self.µ
        if i <= self.s:
            if self.l is None:
                return (self.λ**i/(factorial(i)*self.µ**i))*self.p_zero
            else:
                return (u**i/factorial(i))*self.p_zero
        else:
            if self.l is None:
                return (self.λ**i/(self.s**(i-self.s)*factorial(self.s)*µ**i))*self.p_zero
            else:
                return (u**i/(factorial(self.s)*s**(i-s)))*self.p_zero
    
    def computeNfBar(self):
        if self.l is None:
            self.nf_bar = (self.ρ*self.computePi(self.s))/(1-self.ρ)**2
        else:
            if self.ρ == 1:
                self.nf_bar = self.p_zero*((self.s**self.s)/factorial(s))*((self.l - self.s)(self.l - self.s + 1)/2)
            else:
                self.nf_bar = self.p_zero*(((self.s*self.ρ)**self.s*self.ρ)/(factorial(self.s)*(1-self.ρ)**2))*(1-self.ρ**(self.l-self.s+1)-(1-self.ρ)*(self.l-self.s+1)*self.ρ**(self.l-self.s))
        return self.nf_bar
    
    def computeNsBar(self):
        if self.l is None:
            self.ns_bar = self.nf_bar + self.s*self.ρ
        else:
            pl = self.computePi(self.l)
            self.ns_bar = self.nf_bar + (self.λ*(1 - pl))/self.µ
        return     self.ns_bar
        
    def computeTfBar(self):
        if self.l is None:
            self.tf_bar = self.nf_bar / self.λ
        else:
            pl = self.computePi(self.l)
            self.tf_bar = self.nf_bar / (self.λ*(1-pl))
        return self.tf_bar
        
    def computeTsBar(self):
        self.ts_bar = self.tf_bar + 1 / self.µ
        return self.ts_bar
s = nmbr_serveurs 
system = QueuingSystem(λ, µ, s)
if system.isStationary():
    print(">>> There you go: ")
    print("[+] nf-bar =", system.computeNfBar())
    print("[+] ns-bar =", system.computeNsBar())
    print("[+] tf-bar =", system.computeTfBar())
    print("[+] ts-bar =", system.computeTsBar())
else:
    print("[-] Not stationary")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-33-8a300f181e0e> in <module>()
#      66         return self.ts_bar
#      67 s = nmbr_serveurs
# ---> 68 system = QueuingSystem(λ, µ, s)
#      69 if system.isStationary():
#      70     print(">>> There you go: ")
#
# <ipython-input-33-8a300f181e0e> in __init__(self, λ, μ, s, l)
#      10             self.l = l
#      11         if l is None:
# ---> 12             self.p_zero = (sum((1/factorial(k))*(λ/µ)**k for k in range(s))                           + (1/factorial(s))*((λ/µ)**s)*((s*µ)/(s*µ - λ))                          )**(-1)
#      13         else:
#      14             u = λ / µ
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# Calcule des caractéristiques de simulation :

# %%
print("NS-bar = ",mean(historique_de_systeme))
# Out:
# NS-bar =  5.253532834580216

# %% [markdown]
# Temps de service moyen :

# %%
temps_dans_la_file =[]
for i in range(len(temps_de_sejour)-1):
    temps_dans_la_file.append(temps_de_sejour[i]-temps_de_service[i])
print("temps d'attente moyen = ",float("{0:.2f}".format(mean(temps_dans_la_file))))
# Out:
# temps d'attente moyen =  0.77

# %%
print("Ts-bar= ",float("{0:.2f}".format(mean(temps_de_sejour))))
# Out:
# Ts-bar=  1.76
